# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
image = Image.open("rahul.jpeg")
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1280x853 at 0x22B695DD9A0>

# %%
import numpy as np

# %%
arr = np.array(image)

# %%
arr.shape
# Out:
# (853, 1280, 3)

# %%
cut = arr[:,:,2]
plt.imshow(cut)

# %%
work = arr.copy()

# %%
work[:,:,[1,2]] = 0

# %%
work.shape
# Out:
# (853, 1280, 3)

# %%
plt.imshow(work)

# %%
gray = arr.mean(axis=2)

# %%
plt.imshow(gray,cmap="gray")
