# %%
import numpy as np

# %%
np.random.random(10)
# Out:
# array([0.44682876, 0.54359354, 0.25520564, 0.44751271, 0.80952237,
#        0.88772408, 0.04035066, 0.28867906, 0.36877352, 0.80882845])

# %%
arr = np.random.randint(0,10,size=(2,10))
arr
# Out:
# array([[6, 5, 3, 1, 1, 8, 9, 2, 9, 0],
#        [7, 2, 7, 9, 5, 1, 7, 0, 4, 7]])

# %%
arr.sum(axis=0, keepdims=True)
# Out:
# array([[13,  7, 10, 10,  6,  9, 16,  2, 13,  7]])

# %%
np.linspace(0,10,20)
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0,2*np.pi,200)

# %%
y = np.sin(x)

# %%
plt.plot(x,y)

# %%
r = 10

# %%
theta = np.linspace(0,2*np.pi,200)

# %%
x = r*np.cos(theta)

# %%
y = r*np.sin(theta)

# %%
plt.figure(figsize=(4,4))
plt.plot(x,y)

# %%
x = [1,5,8,9]
y = [10,2,4,2]

# %%
plt.plot(x,y)
